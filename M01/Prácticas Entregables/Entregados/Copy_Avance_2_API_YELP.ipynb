# %%
import pandas as pd
import numpy as np
import seaborn as sns
import requests

# %%
api_key = 'FHVvXoNmTXIl9DuxYis7AV5uLPujm9MLwrhgs5NgvCfaOxd3V6mxt6dQU8eEqYJiGxe816XATx7ufWjbMWqbV-2Uku1jxBJv8BGRC74NroLPl27PDQqs0tDixit-YHYx'
api_url = 'https://api.yelp.com/v3/businesses/search'

# %%
headers = {
    'Authorization': f'Bearer {api_key}'
}

# %% [markdown]
# ## Escogemos la ciudad de nuestro interés

# %%
ciudad = 'San Diego'

# %% [markdown]
# ### Consulta a la API de Yelp para obtener información sobre restaurantes en San Diego

# %%
# Construimos un diccionario con los parámetros exigidos por la API: 'term', 'location' y 'limit'
params = {'term': 'restaurants', 'location': 'San Diego', 'limit':50}

# Creamos una variable llamada 'response'
response = requests.get(api_url, headers=headers, params=params)

# Parseamos o a 'convertir' el 'response' anterior en un dicc de Python
data = response.json()

data
# Out:
# {'businesses': [{'id': 'Sa_qcnc7ZgzSOylf3plTRA',
#    'alias': 'c-level-san-diego-6',
#    'name': 'C Level',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/rE2Ti2kPJTW_xv2FkW-8Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c-level-san-diego-6?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 5326,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 32.72412, 'longitude': -117.18857},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '880 Harbor Island Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
# ...

# %%
rest = pd.json_normalize(data['businesses'], sep=)
# Out:
#   Cell In[60], line 1
#     rest = pd.json_normalize(data['businesses'], sep=)
#                                                  ^
# SyntaxError: expected argument value expression

# %%
# Crear dataframe global
rest = pd.concat(all_rest, ignore_index=True)
rest
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 # Crear dataframe global
# ----> 2 rest = pd.concat(all_rest, ignore_index=True)
#       3 rest
#
# NameError: name 'all_rest' is not defined
