# %% [markdown]
# # Proyecto Integrador

# %% [markdown]
# ## Segundo avance: Conexión con la API Yelp

# %% [markdown]
# ##### Importamos las librerías necesarias:

# %%
import pandas as pd
import requests

# %% [markdown]
# ### 1. Configuración de la API

# %%
# url de la API de Yelp
api_url = "https://api.yelp.com/v3/businesses/search"

# API Key de Yelp
api_key = 'api_key_valida_aqui'

# Configuración de los headers para la autenticación
headers = {'Authorization': f'Bearer {api_key}'}

# %% [markdown]
# Mi ciudad

# %%
ciudad = 'San Diego'

# %% [markdown]
# ### 2. Primera solicitud a Yelp

# %%
# construimos los parámetros de la consulta usando un diccionario: 'term', 'localización' y 'límite'
params = {'term': 'restaurants', 'location': ciudad, 'limit': 50}

# hacemos la solicitud GET a la API de Yelp y la llamamos 'response'
response = requests.get(api_url, headers=headers, params=params)

# convertimos la respuesta JSON en un diccionario de Python
data = response.json()

# imprimimos los datos obtenidos
data
# Out:
# {'error': {'code': 'VALIDATION_ERROR',
#   'description': "'Bearer api_key_valida_aqui' does not match '^(?i)Bearer [A-Za-z0-9\\\\-\\\\_]{128}$'",
#   'field': 'Authorization',
#   'instance': 'Bearer api_key_valida_aqui'}}

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['error'])

# %%
data['total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data['total']
#
# KeyError: 'total'

# %%
data['region']
# Out:
# {'center': {'longitude': -117.15408325195312, 'latitude': 32.790569394537286}}

# %%
data['businesses']
# Out:
# [{'id': 'Sa_qcnc7ZgzSOylf3plTRA',
#   'alias': 'c-level-san-diego-6',
#   'name': 'C Level',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/rE2Ti2kPJTW_xv2FkW-8Lg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/c-level-san-diego-6?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 5329,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 32.72412, 'longitude': -117.18857},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '880 Harbor Island Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['880 Harbor Island Dr', 'San Diego, CA 92101']},
#   'phone': '+16192986802',
#   'display_phone': '(619) 298-6802',
#   'distance': 8072.435852108526},
#  {'id': 'W0dzJ7E6R3kyAOXIlO_tbw',
#   'alias': 'ristorante-illando-san-diego',
#   'name': 'Ristorante Illando',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/EpOoGIXYzsVKpaXyXHQaKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ristorante-illando-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3329,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.724060725245366, 'longitude': -117.168259},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1825 India St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1825 India St', 'San Diego, CA 92101']},
#   'phone': '+16196935204',
#   'display_phone': '(619) 693-5204',
#   'distance': 7523.72779563874},
#  {'id': 'NxvB55P2UCjeAcEPsJwyUw',
#   'alias': 'flama-llama-san-diego',
#   'name': 'Flama Llama',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/zTFZmUWFeDcyaDONL7Zu2w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flama-llama-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3833,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 32.821134, 'longitude': -117.154646},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '4433 Convoy St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4433 Convoy St', 'San Diego, CA 92111']},
#   'phone': '+18584920402',
#   'display_phone': '(858) 492-0402',
#   'distance': 3385.7788056323193},
#  {'id': 'ruZ45_rMndqb7aLEr6VSOw',
#   'alias': 'cesarina-san-diego-3',
#   'name': 'Cesarina',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/qC3UrCYhE5KdiXKA3OM4ag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cesarina-san-diego-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3297,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 32.74331600571442,
#    'longitude': -117.2346220328273},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '4161 Voltaire St',
#    'address2': 'Ste B',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4161 Voltaire St', 'Ste B', 'San Diego, CA 92107']},
#   'phone': '+16192266222',
#   'display_phone': '(619) 226-6222',
#   'distance': 9190.980627174436},
#  {'id': 'OzLEnrpVU69TAnlCzdzLcw',
#   'alias': 'the-remy-san-diego',
#   'name': 'The Remy',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/63cbXgXdgtFNDG9dHdJjag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-remy-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 533,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.76083389437677, 'longitude': -117.187348},
#   'transactions': [],
#   'location': {'address1': '2445 Hotel Circle Pl',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92108',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2445 Hotel Circle Pl', 'San Diego, CA 92108']},
#   'phone': '+16199065570',
#   'display_phone': '(619) 906-5570',
#   'distance': 4548.904998378724},
#  {'id': 'F1k6I7jjEl9RqfVI1HA0iQ',
#   'alias': 'allegro-restaurant-and-bar-san-diego',
#   'name': 'Allegro Restaurant and Bar',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/0EoFGXomLyIGnoVTEArsig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/allegro-restaurant-and-bar-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 2049,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.7216499, 'longitude': -117.1684993},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '1536 India St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1536 India St', 'San Diego, CA 92101']},
#   'phone': '+16193106996',
#   'display_phone': '(619) 310-6996',
#   'distance': 7791.596636863075},
#  {'id': '_0yupuQVwUC_E2KE5q-M4w',
#   'alias': 'wolf-in-the-woods-san-diego',
#   'name': 'Wolf in the Woods',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/icdfseqdMxB6FsH74WltZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wolf-in-the-woods-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 476,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'modern_european', 'title': 'Modern European'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 32.752991901901794,
#    'longitude': -117.18311696441768},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1920 Fort Stockton Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1920 Fort Stockton Dr', 'San Diego, CA 92103']},
#   'phone': '+16192342597',
#   'display_phone': '(619) 234-2597',
#   'distance': 4993.0518826363195},
#  {'id': 'OyB0Kn1JBRBNgWVGS8CwTA',
#   'alias': 'formoosa-san-diego',
#   'name': 'formoosa',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/YDncZqvNqqmHxApT-Ol8yQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/formoosa-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 5212,
#   'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 32.82461, 'longitude': -117.15571},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '4646 Convoy St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4646 Convoy St', 'San Diego, CA 92111']},
#   'phone': '+18585679091',
#   'display_phone': '(858) 567-9091',
#   'distance': 3806.721004912493},
#  {'id': 'iyLfem8zE0fLWTf-4WdqaA',
#   'alias': 'steamy-piggy-san-diego-2',
#   'name': 'Steamy Piggy',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/cgSKPAuwP5uvCa9m5dG7PA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/steamy-piggy-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 7510,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.82558093593696,
#    'longitude': -117.15449932962656},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4681 Convoy St',
#    'address2': 'Ste A',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4681 Convoy St', 'Ste A', 'San Diego, CA 92111']},
#   'phone': '+18584920401',
#   'display_phone': '(858) 492-0401',
#   'distance': 3883.3517649812966},
#  {'id': 'FptrAAOYIiAWkK5raosOIw',
#   'alias': 'gravity-heights-mission-valley-san-diego',
#   'name': 'Gravity Heights - Mission Valley',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/p3aMi0cRthuLAeXz4DfPTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gravity-heights-mission-valley-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 448,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 32.76622027664316,
#    'longitude': -117.1601256362996},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '525 Camino De La Reina',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92108',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['525 Camino De La Reina', 'San Diego, CA 92108']},
#   'phone': '+16195397833',
#   'display_phone': '(619) 539-7833',
#   'distance': 2776.287753414493},
#  {'id': 's47V3FGY6JLX91syCV_HaA',
#   'alias': 'insideout-san-diego-2',
#   'name': 'insideOUT',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/LMCxLVL78HmvVVn0GTa-zw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/insideout-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1282,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.74852913548678,
#    'longitude': -117.14873635215066},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1642 University Ave',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1642 University Ave',
#     'Ste 100',
#     'San Diego, CA 92103']},
#   'phone': '+16198888623',
#   'display_phone': '(619) 888-8623',
#   'distance': 4710.867374555674},
#  {'id': 'mbG2JAAQ33kKuO3PMPUObg',
#   'alias': 'ironside-fish-and-oyster-san-diego',
#   'name': 'Ironside Fish & Oyster',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/la38IxodWcHlW30tXgzd7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ironside-fish-and-oyster-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 5984,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 32.72273395085638,
#    'longitude': -117.16858734903415},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1654 India St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1654 India St', 'San Diego, CA 92101']},
#   'phone': '+16192693033',
#   'display_phone': '(619) 269-3033',
#   'distance': 7674.364985828735},
#  {'id': 'QqVzr_Lwz0iucCccxc8PaQ',
#   'alias': 'khachapuri-san-diego',
#   'name': 'Khachapuri',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/H-DewlxKFh0oTK-Jq8_2pA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/khachapuri-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 25,
#   'categories': [{'alias': 'georgian', 'title': 'Georgian'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 32.75927, 'longitude': -117.14601},
#   'transactions': [],
#   'location': {'address1': '4505 Park Blvd',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92116',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4505 Park Blvd', 'Ste 100', 'San Diego, CA 92116']},
#   'phone': '+16199477177',
#   'display_phone': '(619) 947-7177',
#   'distance': 3566.4291614583835},
#  {'id': 'SzfefzM8P2npwP9X3QL2HA',
#   'alias': 'fortuna-ristorante-italiano-san-diego',
#   'name': 'Fortuna Ristorante Italiano',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/FuZTu02p6QuBOl2y4OL0FQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fortuna-ristorante-italiano-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 188,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.9,
#   'coordinates': {'latitude': 32.75426941462053,
#    'longitude': -117.1460445558336},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '4207 Park Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4207 Park Blvd', 'San Diego, CA 92103']},
#   'phone': '+16193105739',
#   'display_phone': '(619) 310-5739',
#   'distance': 4114.918445581465},
#  {'id': 'S1Ir-iP996tW4BBAv1Cahg',
#   'alias': 'malibu-farm-san-diego-6',
#   'name': 'Malibu Farm',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/YOqF1fZoiqjr8uJT8CaIfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/malibu-farm-san-diego-6?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1970,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.708581, 'longitude': -117.169752},
#   'transactions': [],
#   'location': {'address1': '831 W Harbor Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['831 W Harbor Dr', 'San Diego, CA 92101']},
#   'phone': '+16196952300',
#   'display_phone': '(619) 695-2300',
#   'distance': 9245.027341812578},
#  {'id': 'eXsXpLbMLmbic_nmlfK_zw',
#   'alias': 'pomegranate-russian-georgian-restaurant-san-diego',
#   'name': 'Pomegranate Russian-Georgian Restaurant',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/WRdlKZx7wmOwLeFyrIqhmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pomegranate-russian-georgian-restaurant-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 2240,
#   'categories': [{'alias': 'russian', 'title': 'Russian'},
#    {'alias': 'georgian', 'title': 'Georgian'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.75568, 'longitude': -117.13968},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2312 El Cajon Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92104',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2312 El Cajon Blvd', 'San Diego, CA 92104']},
#   'phone': '+16192984007',
#   'display_phone': '(619) 298-4007',
#   'distance': 4125.57758855553},
#  {'id': 'UFp43HHtNAAPRXLDFZT2uw',
#   'alias': 'noodle-and-bun-san-diego',
#   'name': 'Noodle & Bun',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/pL0YFoXibAo6kwHD4ECBww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noodle-and-bun-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 98,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.9,
#   'coordinates': {'latitude': 32.713363, 'longitude': -117.161261},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '770 Fourth Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['770 Fourth Ave', 'San Diego, CA 92101']},
#   'phone': '+16193563688',
#   'display_phone': '(619) 356-3688',
#   'distance': 8621.591774144897},
#  {'id': '0gi0ArxUwbz5wNqisA0Q6w',
#   'alias': 'leila-san-diego-3',
#   'name': 'Leila',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/8ObW2RlGABKXHBnHE-eKqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/leila-san-diego-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 907,
#   'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'halal', 'title': 'Halal'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.7495329005057,
#    'longitude': -117.13031122021752},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '3956 30th St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92104',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3956 30th St', 'San Diego, CA 92104']},
#   'phone': '+18587233766',
#   'display_phone': '(858) 723-3766',
#   'distance': 5083.017966521048},
#  {'id': '7wgq7FZC9iGSOuTWssFRHg',
#   'alias': 'woomiok-san-diego-4',
#   'name': 'Woomiok',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/a2CuDLrvdY_8AlXPmE-0qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/woomiok-san-diego-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1615,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 32.81414770380241,
#    'longitude': -117.1539641380208},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3860 Convoy St',
#    'address2': 'Ste 113',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3860 Convoy St', 'Ste 113', 'San Diego, CA 92111']},
#   'phone': '+18585661172',
#   'display_phone': '(858) 566-1172',
#   'distance': 2611.8153905893473},
#  {'id': 'iVU8XiOu75ykznvEBbtxZA',
#   'alias': 'freddy-s-chophouse-san-diego',
#   'name': 'Freddy’s Chophouse',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/YVnX7jYkMBzn3UtBFFPvPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/freddy-s-chophouse-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 889,
#   'categories': [{'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.8,
#   'coordinates': {'latitude': 32.711010208476175,
#    'longitude': -117.16117354110432},
#   'transactions': ['restaurant_reservation'],
#   'location': {'address1': '554 Fourth Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['554 Fourth Ave', 'San Diego, CA 92101']},
#   'phone': '+16193917575',
#   'display_phone': '(619) 391-7575',
#   'distance': 8881.599224859941},
#  {'id': 'WG4QTcnlSh4eKylSM6lICg',
#   'alias': 'juniper-and-ivy-san-diego-2',
#   'name': 'Juniper and Ivy',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/LqkBKiHMrUn-yk3SPMzDFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/juniper-and-ivy-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3537,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 32.72747713781323,
#    'longitude': -117.17120094420792},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '2228 Kettner Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2228 Kettner Blvd', 'San Diego, CA 92101']},
#   'phone': '+16192699036',
#   'display_phone': '(619) 269-9036',
#   'distance': 7206.332993518132},
#  {'id': 'PLEh6w_76YwLx6ozXthRmQ',
#   'alias': 'shorebird-san-diego-3',
#   'name': 'Shorebird',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Hj9NL3d1loHxJzee3nD6Ag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shorebird-san-diego-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 72,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.70904214340898,
#    'longitude': -117.17199787423696},
#   'transactions': ['restaurant_reservation'],
#   'location': {'address1': '885 W Harbor Dr',
#    'address2': None,
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['885 W Harbor Dr', 'San Diego, CA 92101']},
#   'phone': '+16198195055',
#   'display_phone': '(619) 819-5055',
#   'distance': 9229.371770397142},
#  {'id': 'eGhOLzFFIhrvF6QjSSpJsg',
#   'alias': 'phils-bbq-san-diego-2',
#   'name': "Phil's BBQ",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/IijLAPbkYwMrvcMgNo_8vw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/phils-bbq-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 16890,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 32.7547792020658, 'longitude': -117.21598848605},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3750 Sports Arena Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3750 Sports Arena Blvd', 'San Diego, CA 92110']},
#   'phone': '+16192266333',
#   'display_phone': '(619) 226-6333',
#   'distance': 7032.5906584811955},
#  {'id': 'aY_z6z6at7wyoW7sFhf4bA',
#   'alias': 'cucina-urbana-san-diego-4',
#   'name': 'Cucina Urbana',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/W3eq1Q3z8jI_uDz8mINbUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cucina-urbana-san-diego-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 4870,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.731246262774796,
#    'longitude': -117.16009352882612},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '505 Laurel St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['505 Laurel St', 'San Diego, CA 92101']},
#   'phone': '+16192392222',
#   'display_phone': '(619) 239-2222',
#   'distance': 6630.566040690313},
#  {'id': 'NohTO4cb5qtBPVa4uNSmrA',
#   'alias': 'piedra-santa-san-diego',
#   'name': 'Piedra Santa',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/IrwakrIy3SjZA6TFWuWFbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piedra-santa-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 229,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 32.71961194920384,
#    'longitude': -117.167591203687},
#   'transactions': [],
#   'location': {'address1': '555 W Ash St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['555 W Ash St', 'San Diego, CA 92101']},
#   'phone': '+16193106207',
#   'display_phone': '(619) 310-6207',
#   'distance': 8000.986775905793},
#  {'id': 'a3yfBL2Nlm6Z6-1Yzl4ncw',
#   'alias': 'din-tai-fung-san-diego-9',
#   'name': 'Din Tai Fung',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/VmEJ0hAKdzeid6JOV9PA5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/din-tai-fung-san-diego-9?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 6343,
#   'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'shanghainese', 'title': 'Shanghainese'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.87220167788749,
#    'longitude': -117.2125967815541},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '4301 La Jolla Village Dr',
#    'address2': 'Ste 2000',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92122',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4301 La Jolla Village Dr',
#     'Ste 2000',
#     'San Diego, CA 92122']},
#   'phone': '+18583755988',
#   'display_phone': '(858) 375-5988',
#   'distance': 10589.631845620803},
#  {'id': 'DqrcWtF6575tHeg7R5Vdfg',
#   'alias': 'labora-san-diego-3',
#   'name': 'Labora',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/foCIDpk9aUDQkmI-E3P9VA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/labora-san-diego-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 65,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.83230458936411, 'longitude': -117.1499588},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '8055 Clairemont Mesa Blvd',
#    'address2': 'Ste 101',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['8055 Clairemont Mesa Blvd',
#     'Ste 101',
#     'San Diego, CA 92111']},
#   'phone': '+18885690660',
#   'display_phone': '(888) 569-0660',
#   'distance': 4646.479426986662},
#  {'id': '0cI9X3aHSdGi7NR6ZiElCA',
#   'alias': 'the-red-door-san-diego',
#   'name': 'The Red Door',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/jb7PBoPm0yqMW2kniq-X6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-red-door-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1732,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.74967, 'longitude': -117.17012},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '741 W Washington St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['741 W Washington St', 'San Diego, CA 92103']},
#   'phone': '+16192956000',
#   'display_phone': '(619) 295-6000',
#   'distance': 4796.4336768242865},
#  {'id': 'j1fM40F8PZKXnnXzY0DgXA',
#   'alias': 'animae-san-diego-4',
#   'name': 'Animae',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/lGtj-VvYGr464C-DTCpB_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/animae-san-diego-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1466,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 32.715116098736864,
#    'longitude': -117.17052267765654},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '969 Pacific Hwy',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['969 Pacific Hwy', 'San Diego, CA 92101']},
#   'phone': '+16194321225',
#   'display_phone': '(619) 432-1225',
#   'distance': 8540.15227923233},
#  {'id': 'l3EU52zX1BUH7KURxNF77Q',
#   'alias': 'carbon-angela-s-kitchen-san-diego',
#   'name': 'Carbon Angela’s Kitchen',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/a-WIRdCjdXxXjqn9KwTHhA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carbon-angela-s-kitchen-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 246,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 32.73021931174349, 'longitude': -117.1296891},
#   'transactions': [],
#   'location': {'address1': '2318 30th St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92104',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2318 30th St', 'San Diego, CA 92104']},
#   'phone': '+16198901234',
#   'display_phone': '(619) 890-1234',
#   'distance': 7096.026546885356},
#  {'id': 'b9XtSjDs4zRisGVmZ9qBhw',
#   'alias': 'yuk-dae-jang-san-diego',
#   'name': 'Yuk Dae Jang',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/5pMq6q0WntoQHZmitJpOzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yuk-dae-jang-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 394,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.831895948715214,
#    'longitude': -117.16058658466224},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '7307 Clairemont Mesa Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['7307 Clairemont Mesa Blvd', 'San Diego, CA 92111']},
#   'phone': '+18587374002',
#   'display_phone': '(858) 737-4002',
#   'distance': 4625.883369863463},
#  {'id': 'gW9QYl6rijkncwPpvdVr7A',
#   'alias': 'coasterra-san-diego',
#   'name': 'Coasterra',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/yhT6V2ib1ijBK_rYGHWiOw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/coasterra-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3939,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.72454637017192,
#    'longitude': -117.18803932290604},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '880 B Harbor Island Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['880 B Harbor Island Dr', 'San Diego, CA 92101']},
#   'phone': '+16198141300',
#   'display_phone': '(619) 814-1300',
#   'distance': 8009.229505676572},
#  {'id': '9Rlax6bJCV44f_77hmcUDA',
#   'alias': 'havana-grill-san-diego-4',
#   'name': 'Havana Grill',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/UlK9m-Z9ImXuSMGjv5h3dw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/havana-grill-san-diego-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 642,
#   'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#    {'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 32.77003099283535,
#    'longitude': -117.14672813323878},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1652 Camino Del Rio N',
#    'address2': 'Ste FS19',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92108',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1652 Camino Del Rio N',
#     'Ste FS19',
#     'San Diego, CA 92108']},
#   'phone': '+16199155699',
#   'display_phone': '(619) 915-5699',
#   'distance': 2393.5850999989934},
#  {'id': '4l6dK7F9a6kPBrK00n4QFw',
#   'alias': 'trust-san-diego',
#   'name': 'Trust',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/5zieh0AfevIwjj6gDIn6gw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/trust-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1579,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 32.74665, 'longitude': -117.14663},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3752 Park Blvd',
#    'address2': 'Ste 105C',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3752 Park Blvd', 'Ste 105C', 'San Diego, CA 92103']},
#   'phone': '+16197956901',
#   'display_phone': '(619) 795-6901',
#   'distance': 4939.014784485331},
#  {'id': 'e60v5yO7LX77Y10A5hA-9A',
#   'alias': 'bahn-thai-san-diego',
#   'name': 'Bahn Thai',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/FaxSyF34xQBKdm-Dp5cB8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bahn-thai-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3413,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 32.7618085751424,
#    'longitude': -117.146594524384},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4646 Park Blvd',
#    'address2': 'Ste 3',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92116',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['4646 Park Blvd', 'Ste 3', 'San Diego, CA 92116']},
#   'phone': '+16192996363',
#   'display_phone': '(619) 299-6363',
#   'distance': 3282.798018196127},
#  {'id': 'sNhSsshDp5fuIhjl99tfng',
#   'alias': 'island-prime-san-diego-3',
#   'name': 'Island Prime',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/QfZ0prB9azuO9e3qfc5KUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/island-prime-san-diego-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 2859,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 32.72413177679145,
#    'longitude': -117.18867135644214},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '880 Harbor Island Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['880 Harbor Island Dr', 'San Diego, CA 92101']},
#   'phone': '+16192986802',
#   'display_phone': '(619) 298-6802',
#   'distance': 8075.08386279481},
#  {'id': '7efJ3Qy7jHjTh4mkBYhIsg',
#   'alias': 'xinjiang-bbq-san-diego',
#   'name': 'Xinjiang  BBQ',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/8OpQhR_yAtTvaL1WMx_9wA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/xinjiang-bbq-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 473,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 32.7841, 'longitude': -117.17007},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6931 Linda Vista Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['6931 Linda Vista Rd', 'San Diego, CA 92111']},
#   'phone': '+18585673988',
#   'display_phone': '(858) 567-3988',
#   'distance': 1668.1037379292304},
#  {'id': 'OfjUGieDXyPB8jWa0pvehA',
#   'alias': 'homestyle-hawaiian-san-diego',
#   'name': 'Homestyle Hawaiian',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/QumFe0AQnSEBUJ5EojvOvw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/homestyle-hawaiian-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 2269,
#   'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 32.80164, 'longitude': -117.15914},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '7524 Mesa College Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['7524 Mesa College Dr', 'San Diego, CA 92111']},
#   'phone': '+18585715828',
#   'display_phone': '(858) 571-5828',
#   'distance': 1316.798996154296},
#  {'id': '4Rp6_SYnJVqLHi3WyUQTNQ',
#   'alias': 'aka-san-diego-2',
#   'name': 'AKA',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/QAO65pKE6dQG8k7pnlwleg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aka-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 382,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 32.711736714556615, 'longitude': -117.1598845},
#   'transactions': [],
#   'location': {'address1': '611 Fifth Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['611 Fifth Ave', 'San Diego, CA 92101']},
#   'phone': '+16197800430',
#   'display_phone': '(619) 780-0430',
#   'distance': 8792.736643010463},
#  {'id': 'Pk2P75bi2cjZdr6oxyg6zQ',
#   'alias': 'tabu-shabu-north-park-san-diego',
#   'name': 'Tabu Shabu - North Park',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Dma5wnD3LJCd3YlcXAC7dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tabu-shabu-north-park-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 674,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 32.7451128, 'longitude': -117.1299451},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3647 30th St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92104',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3647 30th St', 'San Diego, CA 92104']},
#   'phone': '+16194080369',
#   'display_phone': '(619) 408-0369',
#   'distance': 5548.897651808711},
#  {'id': 'X8EmtgsqlB9QHJ7HH-FiIw',
#   'alias': 'park-social-san-diego-2',
#   'name': 'Park Social',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/MXdLy5GMO2qDYnYQAMUdyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/park-social-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 597,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 32.827702962048726,
#    'longitude': -117.14007543626931},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '8720 Ariva Ct',
#    'address2': 'Ste 10',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92123',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['8720 Ariva Ct', 'Ste 10', 'San Diego, CA 92123']},
#   'phone': '+18587374310',
#   'display_phone': '(858) 737-4310',
#   'distance': 4321.045503732581},
#  {'id': 'BCruNRwhpJDD9HCkdv7pvA',
#   'alias': 'flor-s-farm-to-table-san-diego-2',
#   'name': 'Flor’s Farm to Table',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/P9JpBCYjWagyn-O-sKQXHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flor-s-farm-to-table-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 441,
#   'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 32.7525957133457,
#    'longitude': -117.19625050000002},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2548 Congress St',
#    'address2': 'Ste G',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2548 Congress St', 'Ste G', 'San Diego, CA 92110']},
#   'phone': '+16196897013',
#   'display_phone': '(619) 689-7013',
#   'distance': 5786.5917687207375},
#  {'id': '0t0AfOKctJebkYb89G1vdg',
#   'alias': 'barbusa-san-diego',
#   'name': 'Barbusa',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/qwIoe4qiu7QTw4TySyBihA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barbusa-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3648,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 32.724807, 'longitude': -117.168491},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1917 India St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1917 India St', 'San Diego, CA 92101']},
#   'phone': '+16192381917',
#   'display_phone': '(619) 238-1917',
#   'distance': 7445.969557254728},
#  {'id': 'XZPpWp9-zcIHQ3SJIgqnQQ',
#   'alias': 'romanella-cucina-romana-san-diego-2',
#   'name': 'Romanella Cucina Romana',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/belZgIIHuYxTO4bxKQ-_qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/romanella-cucina-romana-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 134,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.9,
#   'coordinates': {'latitude': 32.795, 'longitude': -117.19218},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '3055 Clairemont Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92117',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3055 Clairemont Dr', 'San Diego, CA 92117']},
#   'phone': '+16192720384',
#   'display_phone': '(619) 272-0384',
#   'distance': 3698.566986189597},
#  {'id': 'EAqSJcj83DIHJyMNM6HEmQ',
#   'alias': 'flor-s-san-diego',
#   'name': 'Flor’s',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/dOcL9d6O1ZbcbzUBS9PqVA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flor-s-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 4,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 32.7528833, 'longitude': -117.19459731210706},
#   'transactions': [],
#   'location': {'address1': '2476 San Diego Ave',
#    'address2': 'Ste A',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2476 San Diego Ave', 'Ste A', 'San Diego, CA 92110']},
#   'phone': '+16196897013',
#   'display_phone': '(619) 689-7013',
#   'distance': 5658.531044716998},
#  {'id': 'CBZUZCTTGKMyAo757_NJew',
#   'alias': 'herb-and-wood-san-diego',
#   'name': 'Herb & Wood',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/M8Q6cOoXBXsRFdVGo4CdnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/herb-and-wood-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 2178,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 32.72734705067035,
#    'longitude': -117.17100661443716},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '2210 Kettner Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2210 Kettner Blvd', 'San Diego, CA 92101']},
#   'phone': '+16199558495',
#   'display_phone': '(619) 955-8495',
#   'distance': 7216.42051233327},
#  {'id': 'TeJriPCR04Ouv359ijpTrg',
#   'alias': 'the-prado-san-diego-2',
#   'name': 'The Prado',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/DJcK7WcJvLhhGeT--i9zgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-prado-san-diego-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3568,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 32.7311055, 'longitude': -117.1495474},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '1549 El Prado',
#    'address2': 'Ste 12',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1549 El Prado', 'Ste 12', 'San Diego, CA 92101']},
#   'phone': '+16195579441',
#   'display_phone': '(619) 557-9441',
#   'distance': 6635.402295414958},
#  {'id': '3YhbkLhemwZLIwkoygSD1A',
#   'alias': 'tom-hams-lighthouse-san-diego',
#   'name': "Tom Ham's Lighthouse",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/GmywGxI-ZiIqeFPTT5bC4g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tom-hams-lighthouse-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3053,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 32.724241, 'longitude': -117.213072},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '2150 Harbor Island Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92101',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2150 Harbor Island Dr', 'San Diego, CA 92101']},
#   'phone': '+16192919110',
#   'display_phone': '(619) 291-9110',
#   'distance': 9220.076204840894},
#  {'id': '3E-KCTwLlWukROhCXarTvQ',
#   'alias': 'mabels-gone-fishing-san-diego',
#   'name': "Mabel's Gone Fishing",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/8AUAwoPkUm3v1HlYS9kDbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mabels-gone-fishing-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 474,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'spanish', 'title': 'Spanish'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 32.74679836103475,
#    'longitude': -117.13025953620676},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '3770 30th St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Diego',
#    'zip_code': '92104',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3770 30th St', 'San Diego, CA 92104']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 5360.238737261643},
#  {'id': 'QMfwDVpspp8yuPdx3FfGBw',
#   'alias': 'mikes-red-tacos-point-loma-san-diego',
#   'name': "Mike's Red Tacos - Point Loma",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/k6CCOsvLHu3u-7D0SwMUrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mikes-red-tacos-point-loma-san-diego?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 811,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.8,
#   'coordinates': {'latitude': 32.748692, 'longitude': -117.206062},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3365 Rosecrans St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Diego',
#    'zip_code': '92110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3365 Rosecrans St', 'San Diego, CA 92110']},
#   'phone': '+16192289032',
#   'display_phone': '(619) 228-9032',
#   'distance': 6742.126611856717}]

# %%
len(data['businesses'])
# Out:
# 50

# %%
data['businesses'][17] # Información del restaurante en la posición 18va (comienza la cuenta en cero)
# Out:
# {'id': '0gi0ArxUwbz5wNqisA0Q6w',
#  'alias': 'leila-san-diego-3',
#  'name': 'Leila',
#  'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/8ObW2RlGABKXHBnHE-eKqQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/leila-san-diego-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#  'review_count': 907,
#  'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#   {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#   {'alias': 'halal', 'title': 'Halal'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 32.7495329005057,
#   'longitude': -117.13031122021752},
#  'transactions': [],
#  'price': '$$$$',
#  'location': {'address1': '3956 30th St',
#   'address2': None,
#   'address3': '',
#   'city': 'San Diego',
#   'zip_code': '92104',
#   'country': 'US',
#   'state': 'CA',
#   'display_address': ['3956 30th St', 'San Diego, CA 92104']},
#  'phone': '+18587233766',
#  'display_phone': '(858) 723-3766',
#  'distance': 5083.017966521048}

# %% [markdown]
# ¿Cómo extraer la mayor cantidad de resultados posibles desde la API y convertir la respuesta en un DataFrame?

# %% [markdown]
# ###### La API cuenta con información relativa a 4000 restaurantes, pero en cada consulta se extrae una página con 50 resultados. Por lo tanto, para extraer todos los datos será necesario iterar el proceso. El parámetro offset de la API indica el número de registros a avanzar en cada consulta (avanzamos de 50 en 50).

# %% [markdown]
# ### 3. Paginación y normalización

# %%
# iterar y fijamos el offset
offset = 0

# ciudad
ciudad = 'San Diego'

# creo una lista que contenga los dataframes creados en cada consulta
all_restaurants = [] # [dataframe1, dataframe2, dataframe3, dataframe4]

# voy a iterar hasta alcanzar 200 resultados (límite de Yelp)
while offset <= 150: # actualizo el parámetro offset en cada iteración
    # parámetros de la API
    params = {'term': 'restaurants', 'location': ciudad, 'limit': 50, 'offset': offset}

    # creo una variable 'response que albergue el resultado de la consulta a la API de Yelp
    response = requests.get(api_url, headers=headers, params=params)

    # convierto la respuesta en un diccionario de Python
    data = response.json()

      # voy a usar el método json_normalize de pandas para convertir la lista de negocios en un DataFrame
    rest = pd.json_normalize(data['businesses'], sep='_', record_path=['categories'],
                             meta=['name', 'rating', 'review_count', 'is_closed', 'price', ['location.address1']],
                             errors='ignore')
    
    rest['city'] = ciudad
    
    # agrego el dataframe a la lista
    all_restaurants.append(rest)

    # incremento el offset en 50 para la siguiente iteración
    offset = offset + 50

    # condición de salida del bucle en caso de no haber más negocios
    if 'businesses' not in data or len(data['businesses']) == 0:
       break

# %%
type(rest)
# Out:
# pandas.core.frame.DataFrame

# %%
len(rest)
# Out:
# 110

# %%
len(all_restaurants)
# Out:
# 4

# %%
rest = pd.concat(all_restaurants, ignore_index=True)
rest
# Out:
#             alias           title                                 name rating  \
# 0     newamerican    New American                              C Level    4.3
# 1         seafood         Seafood                              C Level    4.3
# 2           steak     Steakhouses                              C Level    4.3
# 3         italian         Italian                   Ristorante Illando    4.4
# 4           latin  Latin American                          Flama Llama    4.7
# ..            ...             ...                                  ...    ...
# 484  cocktailbars   Cocktail Bars             EE NAMI Tonkatsu Izakaya    4.5
# 485          thai            Thai                              Tid Din    4.4
# 486       lounges         Lounges  Harbor & Sky Rooftop Bar and Lounge    4.0
# 487   newamerican    New American  Harbor & Sky Rooftop Bar and Lounge    4.0
# 488     ethiopian       Ethiopian                                Gihon    4.9
#
#     review_count is_closed price location.address1       city
# 0           5329     False    $$               NaN  San Diego
# 1           5329     False    $$               NaN  San Diego
# 2           5329     False    $$               NaN  San Diego
# 3           3329     False    $$               NaN  San Diego
# 4           3833     False    $$               NaN  San Diego
# ..           ...       ...   ...               ...        ...
# 484          659     False    $$               NaN  San Diego
# 485            8     False   NaN               NaN  San Diego
# 486          126     False    $$               NaN  San Diego
# 487          126     False    $$               NaN  San Diego
# 488           36     False   NaN               NaN  San Diego
#
# [489 rows x 9 columns]

# %% [markdown]
# ### 4. Agrupación de categorías

# %%
categoria_por_restaurante = (rest.groupby('name')['title']
    .apply(lambda x: ", ".join(x.unique()))
    .reset_index()
    .rename(columns={'title':'categories'}))

# %% [markdown]
# ##### Obtengo el DF base sin duplicaciones:

# %%
cols_base = ['name', 'rating', 'review_count', 'is_closed',
    'price', 'city']

rest_base = rest[cols_base].drop_duplicates(subset='name')

# %% [markdown]
# ##### Uno las categorías con info base

# %%
df_final = rest_base.merge(categoria_por_restaurante, on='name', how='left')
df_final.head()
# Out:
#                  name rating review_count is_closed price       city  \
# 0             C Level    4.3         5329     False    $$  San Diego
# 1  Ristorante Illando    4.4         3329     False    $$  San Diego
# 2         Flama Llama    4.7         3833     False    $$  San Diego
# 3            Cesarina    4.7         3297     False   $$$  San Diego
# 4            The Remy    4.5          533     False   NaN  San Diego
#
#                                categories
# 0      New American, Seafood, Steakhouses
# 1                                 Italian
# 2  Latin American, Peruvian, Asian Fusion
# 3        Italian, Cocktail Bars, Desserts
# 4            Steakhouses, Desserts, Salad

# %% [markdown]
# ### 5. Verifico la calidad de los datos

# %% [markdown]
# ##### Valores nulos:

# %%
df_final.isnull().sum()
# Out:
# name             0
# rating           0
# review_count     0
# is_closed        0
# price           38
# city             0
# categories       0
# dtype: int64

# %% [markdown]
# ##### Duplicados:

# %%
df_final['name'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          197 non-null    object
#  1   rating        197 non-null    object
#  2   review_count  197 non-null    object
#  3   is_closed     197 non-null    object
#  4   price         159 non-null    object
#  5   city          197 non-null    object
#  6   categories    197 non-null    object
# dtypes: object(7)
# memory usage: 10.9+ KB

# %% [markdown]
# ### 6. Tratamiento de los datos nulos

# %% [markdown]
# ##### Decido darle un tratamiento a los valores nulos que me trae la columna 'price'. En particular, colocarle la leyenda 'Unknown', pero en una nueva columna llamada 'price_clean':

# %%
df_final['price_clean'] = df_final['price'].fillna('Unknown')

# %% [markdown]
# ##### Verfico el tratamiento de estas celdas trayendo las primeras 5 o hasta ver un valor NaN junto a un valor Unknown:

# %%
df_final[['price', 'price_clean']].head(5)
# Out:
#   price price_clean
# 0    $$          $$
# 1    $$          $$
# 2    $$          $$
# 3   $$$         $$$
# 4   NaN     Unknown

# %% [markdown]
# ###### Arriba se observa que en el registro con valores 'NaN', en la celda price_clean se lee 'Unknown' al tiempo que en la misma columna (clean) se respeta el valor del registro original.

# %%
df_final.head(10)
# Out:
#                                name rating review_count is_closed price  \
# 0                           C Level    4.3         5329     False    $$
# 1                Ristorante Illando    4.4         3329     False    $$
# 2                       Flama Llama    4.7         3833     False    $$
# 3                          Cesarina    4.7         3297     False   $$$
# 4                          The Remy    4.5          533     False   NaN
# 5        Allegro Restaurant and Bar    4.0         2049     False   $$$
# 6                 Wolf in the Woods    4.6          476     False   $$$
# 7                          formoosa    4.7         5212     False    $$
# 8                      Steamy Piggy    4.4         7510     False    $$
# 9  Gravity Heights - Mission Valley    4.6          448     False    $$
#
#         city                               categories price_clean
# 0  San Diego       New American, Seafood, Steakhouses          $$
# 1  San Diego                                  Italian          $$
# 2  San Diego   Latin American, Peruvian, Asian Fusion          $$
# 3  San Diego         Italian, Cocktail Bars, Desserts         $$$
# 4  San Diego             Steakhouses, Desserts, Salad     Unknown
# 5  San Diego  Italian, Venues & Event Spaces, Seafood         $$$
# 6  San Diego   Wine Bars, Modern European, Tapas Bars         $$$
# 7  San Diego         Taiwanese, Coffee & Tea, Noodles          $$
# 8  San Diego             Chinese, Asian Fusion, Ramen          $$
# 9  San Diego   Breakfast & Brunch, American, Brewpubs          $$

# %% [markdown]
# ### 7. Exporto a CSV

# %%
df_final.to_csv("yelp_restaurants_sandiego.csv", index=False)
