# %%
import numpy as np

# %%
edades_miembros = np.array([22, 19, 24, 28, 26, 30, 23])

# %%
print("Edades de los miembros del equipo de fútbol:", edades_miembros)
# Out:
# Edades de los miembros del equipo de fútbol: [22 19 24 28 26 30 23]

# %%
asistencias = np.array([10, 15, 12, 9, 20, 11])  # ejemplo de frecuencias
promedio = asistencias.mean()

# %%
cuotas = np.array([3000, 3500, 2800, 4000])
cuotas_actualizadas = cuotas * 1.1  # aplicar aumento del 10 %

# %%
frecuencias = np.array([8, 12, 5, 20, 15])
activos = frecuencias > 10  # socios frecuentes
print(frecuencias[activos])  # muestra solo los frecuentes
# Out:
# [12 20 15]
