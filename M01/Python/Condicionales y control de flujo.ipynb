# %% [markdown]
# # Condicionales y control de flujo

# %%
a=5
b=7

# %%
if a<b:
    print("a es menor que b")
elif a>b:
    print("a es mayor que b")
else:
    print("a y b son iguales")
# Out:
# a es menor que b

# %%
x=10

if x>0:
    print("x es positivo")
# Out:
# x es positivo

# %%
x=10
if x>0:
print("x es positivo")
# Out:
#   Cell In[8], line 3
#     print("x es positivo")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
num=5
if num>10:
    print("Soy mayor")
elif num<10:
    print("Soy menor")
else: print("Soy igual")
# Out:
# Soy menor

# %%
num=10
if num>10:
    print("Soy mayor")
elif num<10:
    print("Soy menor")
else: print("Soy igual")
# Out:
# Soy igual

# %%
num=5
if num>10:
    print("Soy mayor")
elif num<10:
    print("Soy menor que 10 y primera verdadera. Me voy a ejecutar yo.")
elif num<7:
    print("Soy también menor")
else: print("Soy igual")
# Out:
# Soy menor que 10 y primera verdadera. Me voy a ejecutar yo.
