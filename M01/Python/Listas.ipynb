# %%
[22, 23, 24, 25]
# Out:
# [22, 23, 24, 25]

# %%
["rojo", "azul", "amarillo"]
# Out:
# ['rojo', 'azul', 'amarillo']

# %%
["rojo", 21, 2.5]
# Out:
# ['rojo', 21, 2.5]

# %%
colores=["rojo", "azul", "amarillo"]
numeros=[22, 23, 24, 25]
lista_vacia=[]

# %%
print(colores)
print(numeros)
print(lista_vacia)
# Out:
# ['rojo', 'azul', 'amarillo']
# [22, 23, 24, 25]
# []

# %%
print(type(colores))
# Out:
# <class 'list'>

# %%
mi_lista=["azul", "rojo", "amarillo", "naranja", "violeta"]
print(mi_lista[2])
# Out:
# amarillo

# %%
mi_lista.insert(2, "negro")
print(mi_lista)
# Out:
# ['azul', 'rojo', 'negro', 'negro', 'amarillo', 'naranja', 'violeta']

# %%
mi_lista.extend(["rosa", "gris"])
print(mi_lista)
# Out:
# ['azul', 'rojo', 'negro', 'negro', 'amarillo', 'naranja', 'violeta', 'rosa', 'gris', 'rosa', 'gris']

# %%
mi_lista.index("naranja")
# Out:
# 5

# %%
mi_lista.remove("negro")
print(mi_lista)
# Out:
# ['azul', 'rojo', 'amarillo', 'naranja', 'violeta', 'rosa', 'gris', 'rosa', 'gris']

# %%
lista=[1,5,9,3,2,6,4]

# %%
lista.sort()

# %%
print(lista)
# Out:
# [1, 2, 3, 4, 5, 6, 9]

# %%
mi_lista_alf=["rojo", "azul", "negro", "amarillo"]

# %%
mi_lista_alf.sort()

# %%
print(mi_lista_alf)
# Out:
# ['amarillo', 'azul', 'negro', 'rojo']
