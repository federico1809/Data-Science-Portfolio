# %%
num=5.3
print(type(num))
# Out:
# <class 'float'>

# %%
int(num) #convierte mi num a entero
# Out:
# 5

# %%
int("hola")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int("hola")
#
# ValueError: invalid literal for int() with base 10: 'hola'

# %%
num = "8"
type(num)
# Out:
# str

# %%
int(num) #muestra al 8 sin comillas porque antes era string, ahora numero
# Out:
# 8

# %%
num = "8.5"
print(type(num))
# Out:
# <class 'str'>

# %%
num3=float(num) #convertimos a flotante y guardo en nueva variable

# %%
print(type(num)) #tipo de variable string
print(type(num3)) #tipo de variable float, de acuerdo a lo definido en las líneas anteriores
# Out:
# <class 'str'>
# <class 'float'>

# %%
num=4
print(type(num))
# Out:
# <class 'int'>

# %%
num4=float(num) #convertimos a float y guardamos en una nueva variable

# %%
print(type(num)) #tipo de variable string
print(type(num4)) #tipo de variable float
# Out:
# <class 'int'>
# <class 'float'>

# %%
x=10 #declaramos un entero como variable
print(type(x)) #compruebo qué tipo de dato es x
y=str(x) #convierto la variable x que es un entero a string
print(type(y)) #imprimo el tipo de dato que es y
# Out:
# <class 'int'>
# <class 'str'>

# %%
w=2.2 #w es una variable con un tipo de dato float
print(type(w)) #compruebo el tipo de dato
z= str(w) #convierto la variable float a string
print(type(z)) #compruebo el tipo de dato
# Out:
# <class 'float'>
# <class 'str'>
