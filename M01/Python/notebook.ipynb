# %% [markdown]
# Proyecto Data Science - Parte 2

# %%
print("Esto es un Jupyter Notebook")
# Out:
# Esto es un Jupyter Notebook

# %%
# Este es mi primer uso de f-strings:
x = 3
print(f"Este es el valor de 'x': {x}")
# Out:
# Este es el valor de 'x': 3
