# %%
import numpy as np

# %%
edades_miembros = np.array([22, 19, 24, 28, 26, 30, 23])

# %%
print("Edades de los miembros del equipo:", edades_miembros)
# Out:
# Edades de los miembros del equipo: [22 19 24 28 26 30 23]
