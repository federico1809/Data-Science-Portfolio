# %%
'mano'=='mano'
# Out:
# True

# %%
4==2*2
# Out:
# True

# %%
4=='4'
# Out:
# False

# %%
print(type(4))
print(type('4'))
# Out:
# <class 'int'>
# <class 'str'>

# %%
4 != "4"
# Out:
# True

# %%
9 != 4+5
# Out:
# False

# %%
12 < 15
# Out:
# True

# %%
12 > 15
# Out:
# False

# %%
num1=12
num2=15

# %%
num1<num2
# Out:
# True

# %%
#OPERACIONES DE ASIGNACIÓN

# %%
x=10

# %%
x+=5

# %%
print(x)
# Out:
# 15

# %%
x-=2

# %%
print(x)
# Out:
# 13

# %%
x*=2

# %%
print(x)
# Out:
# 26

# %%
x/=13

# %%
print(x)
# Out:
# 2.0

# %%
#OPERACIONES DE CONCATENACION

# %%
"Hola " + "Henry"
# Out:
# 'Hola Henry'

# %%
"Ja" + "ja" * 3
# Out:
# 'Jajajaja'
