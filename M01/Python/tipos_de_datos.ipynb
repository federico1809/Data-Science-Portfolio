# %%
x=5 # entero

# %%
numero=9.3 #float

# %%
apellido= 'Pérez'

# %%
nombre= 'Paula'

# %%
print(x)
# Out:
# 5

# %%
type(x) #tipo es número entero
# Out:
# int

# %%
print(nombre)
print(apellido)
# Out:
# Paula
# Pérez

# %%
print(type(nombre)) #tipo string
print(type(numero)) #tipo núm flotante
# Out:
# <class 'str'>
# <class 'float'>

# %%
bool(x) #x es 5, por lo tanto un valor verdadero
# Out:
# True

# %%
num=0
bool(num) #cero es false
# Out:
# False
