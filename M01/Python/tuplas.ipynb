# %%
mi_tupla=(1, 2, 3, 4, 5, 6, 7)

# %%
print(mi_tupla)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
type(mi_tupla)
# Out:
# tuple

# %%
tupla_dias=("domingo", "lunes", "martes", "miércoles", "jueves", "viernes", "sábado")

# %%
print(tupla_dias[3])
# Out:
# miércoles

# %%
"viernes" in(tupla_dias)
# Out:
# True

# %%
"juernes" in tupla_dias
# Out:
# False

# %%
tupla_dias.count("sabado")
# Out:
# 0

# %%
tupla_dias.count("sábado")
# Out:
# 1

# %%
x=11
y=22
z="Henry"

# %%
mi_tupla=x,y,z
print(mi_tupla)
# Out:
# (11, 22, 'Henry')

# %%
type(mi_tupla)
# Out:
# tuple

# %%
date=22,"agosto",1999

# %%
type(date)
# Out:
# tuple

# %%
uno,dos,tres=date

# %%
print(uno) 
print(dos)
print(tres)
# Out:
# 22
# agosto
# 1999

# %%
uno,dos=date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 uno,dos=date
#
# ValueError: too many values to unpack (expected 2, got 3)

# %%
uno,dos,tres,cuatro=date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 uno,dos,tres,cuatro=date
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
tupla_impares=1,3,5,7,9

# %%
primero=tupla_impares[0]
cuarto=tupla_impares[3]

# %%
print(primero)
print(cuarto)
# Out:
# 1
# 7
