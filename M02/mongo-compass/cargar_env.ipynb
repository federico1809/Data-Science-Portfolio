# %%
import os
from dotenv import load_dotenv

# Cargar archivo .env con nombre personalizado
dotenv_path = "C:/Users/feder/Documents/Data_Science/m02/mongo-compass/keymongo.env"
load_dotenv(dotenv_path=dotenv_path)

# Asignar variables
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["VOYAGE_API_KEY"] = os.getenv("VOYAGE_API_KEY")
MONGODB_URI = os.getenv("MONGO_URI")

# Verificar carga
print("OPENAI_API_KEY:", os.environ.get("OPENAI_API_KEY")[:5], "...")
print("VOYAGE_API_KEY:", os.environ.get("VOYAGE_API_KEY")[:5], "...")
print("MONGO_URI:", MONGODB_URI[:30], "...")
# Out:
# OPENAI_API_KEY: tu_ap ...
# VOYAGE_API_KEY: tu_ap ...
# MONGO_URI: mongodb+srv://parulito:AtenaKa ...
